# %%
# %load_ext autoreload
# %autoreload 2

# %%
from real_estate.analysis import property_performance

# %%
realestate_df, stocks_df, meta = property_performance(
    purchase_price = 400e3,
    downpayment = 20e3,
    rehab_cost = 20e3,
    after_repair_value = 500e3,
    value_appreciation=0.04,
    monthly_rent_income=4000.,
    margin_multiplier=1.25,
    rent_appreciation=0.03,
    job_monthly_cashflow=2000,
    monthly_rent_expense=700,
    refi_loan_frac=0.8
)
# Out:
# Acquisition:
# Down Payment: $20000.0
# Loan Amount: $383800.0
# Loan Points/Fees: $3800.0
# Closing costs: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2425.88
# Owning Expenses: $781.50
#    Taxes: $178.33
#    Insurance: $83.33
#    HOA: $0.00
#    PMI: $319.83
#    Utilities: $200.00
# Monthly Outflow: $3207.38
# Home Value Appreciation: 4.0%
#
# Rehab:
# Rehab cost: $20000.00
# Holding costs: $19244.26
# Monthly P&I: $2425.88
# Rehab time: 6 months
# Owning expenses: $781.50
#
# Initial Rental Period:
# Monthly Income: $4000.0
# Monthly Operating Expenses: $1381.50
#    Vacancy: $200.00
#    Capex: $200.00
#    Owning Expenses: $781.50
#    Repairs: $200.00
# Monthly Cashflow: $192.62
# NOI: $31422.00
#
# Refinance:
# Loan Amount: $404000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2553.55
# Home Value Appreciaion: 4.0%
#
# Initial real estate cash required 44000.0
# Real Estate Performance
# ...

# %%
realestate_df, stocks_df, meta = property_performance(
    purchase_price = 400e3,
    downpayment = 400e3*0.13,
    rehab_cost = 40e3,
    after_repair_value = 680e3,
    value_appreciation=0.04,
    monthly_rent_income=3000.,
    margin_multiplier=1.0,
    rent_appreciation=0.03,
    job_monthly_cashflow=1000,
    monthly_rent_expense=700,
    refi_loan_frac=0.8
)
# Out:
# Acquisition:
# Down Payment: $52000.0
# Loan Amount: $351480.0
# Loan Points/Fees: $3480.0
# Closing costs: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2221.59
# Owning Expenses: $754.57
#    Taxes: $178.33
#    Insurance: $83.33
#    HOA: $0.00
#    PMI: $292.90
#    Utilities: $200.00
# Monthly Outflow: $2976.16
# Home Value Appreciation: 4.0%
#
# Rehab:
# Rehab cost: $40000.00
# Holding costs: $17856.96
# Monthly P&I: $2221.59
# Rehab time: 6 months
# Owning expenses: $754.57Monthly Outflow: $2976.16
#
#
# Initial Rental Period:
# Monthly Income: $3000.0
# Monthly Operating Expenses: $1204.57
#    Vacancy: $150.00
#    Capex: $150.00
#    Owning Expenses: $754.57
#    Repairs: $150.00
# Monthly Cashflow: $-426.16
# NOI: $21545.20
#
# Refinance:
# Loan Amount: $549440.0
# Loan Points/Fees: $5440.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $3472.83
# Home Value Appreciaion: 4.0%
#
# Initial real estate cash required 96000.0
# ...
