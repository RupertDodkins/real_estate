# %%
from real_estate.analysis import property_performance

property_performance(
    purchase_price = 200e3,
    downpayment = 20e3,
    rehab_cost = 25e3,
    after_repair_value = 225e3,
)
# Out:
# Acquisition:
# Down Payment: $20000.0
# Loan Amount: $182000.0
# Loan Points/Fees: $2000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $1150.36
# Home Value Appreciaion: $6.0%
#
# Rehab:
# Holding costs: $10117.18
# Monthly P&I: $1150.36
# Rehab time: 6 months
# Owning expenses: $535.8333333333334
#
# Initial Rental Period:
# Monthly Income: $3000.0
# Monthly Expenses: $2136.20
# Monthly Cashflow: $863.80
# NOI: $24170.0
#
# Refinance:
# Loan Amount: $182250.0
# Loan Points/Fees: $2250.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $1151.94
# Home Value Appreciaion: 6.0%
# 47000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00           18,000.00           5,920.00
# 1    1.00   12.00          12.00           37,100.00          12,200.00
# 2    2.00   24.00          12.00           38,200.00          12,600.00
# 3    3.00   36.00          12.00           39,300.00          12,900.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 20e3,
    rehab_cost = 25e3,
    after_repair_value = 425e3,
)
# Out:
# Acquisition:
# Down Payment: $20000.0
# Loan Amount: $384000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2427.14
# Home Value Appreciaion: $6.0%
#
# Rehab:
# Holding costs: $18787.85
# Monthly P&I: $2427.14
# Rehab time: 6 months
# Owning expenses: $704.1666666666667
#
# Initial Rental Period:
# Monthly Income: $3000.0
# Monthly Expenses: $3581.31
# Monthly Cashflow: $-581.31
# NOI: $22149.999999999996
#
# Refinance:
# Loan Amount: $344250.0
# Loan Points/Fees: $4250.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2175.89
# Home Value Appreciaion: 6.0%
# 49000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00           18,000.00           6,920.00
# 1    1.00   12.00          12.00           37,100.00          14,300.00
# 2    2.00   24.00          12.00           38,200.00          14,700.00
# 3    3.00   36.00          12.00           39,300.00          15,100.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 20e3,
    rehab_cost = 25e3,
    after_repair_value = 425e3,
    monthly_rent=1000
)
# Out:
# Acquisition:
# Down Payment: $20000.0
# Loan Amount: $384000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2427.14
# Home Value Appreciaion: $6.0%
#
# Rehab:
# Holding costs: $18787.85
# Monthly P&I: $2427.14
# Rehab time: 6 months
# Owning expenses: $704.1666666666667
#
# Initial Rental Period:
# Monthly Income: $1000
# Monthly Expenses: $3281.31
# Monthly Cashflow: $-2281.31
# NOI: $1749.9999999999964
#
# Refinance:
# Loan Amount: $344250.0
# Loan Points/Fees: $4250.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2175.89
# Home Value Appreciaion: 6.0%
# 49000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00            6,000.00           5,120.00
# 1    1.00   12.00          12.00           12,400.00          10,600.00
# 2    2.00   24.00          12.00           12,700.00          10,900.00
# 3    3.00   36.00          12.00           13,100.00          11,200.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 20e3,
    rehab_cost = 25e3,
    after_repair_value = 425e3,
    monthly_rent=100
)
# Out:
# Acquisition:
# Down Payment: $20000.0
# Loan Amount: $384000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2427.14
# Home Value Appreciaion: $6.0%
#
# Rehab:
# Holding costs: $18787.85
# Monthly P&I: $2427.14
# Rehab time: 6 months
# Owning expenses: $704.1666666666667
#
# Initial Rental Period:
# Monthly Income: $100
# Monthly Expenses: $3146.31
# Monthly Cashflow: $-3046.31
# NOI: $-7430.000000000004
#
# Refinance:
# Loan Amount: $344250.0
# Loan Points/Fees: $4250.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2175.89
# Home Value Appreciaion: 6.0%
# 49000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00              600.00           4,320.00
# 1    1.00   12.00          12.00            1,240.00           8,890.00
# 2    2.00   24.00          12.00            1,270.00           9,160.00
# 3    3.00   36.00          12.00            1,310.00           9,430.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 20e3,
    rehab_cost = 25e3,
    after_repair_value = 425e3,
    monthly_rent=0
)
# Out:
# Acquisition:
# Down Payment: $20000.0
# Loan Amount: $384000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2427.14
# Home Value Appreciaion: $6.0%
#
# Rehab:
# Holding costs: $18787.85
# Monthly P&I: $2427.14
# Rehab time: 6 months
# Owning expenses: $704.1666666666667
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $3131.31
# Monthly Cashflow: $-3131.31
# NOI: $-8450.000000000004
#
# Refinance:
# Loan Amount: $344250.0
# Loan Points/Fees: $4250.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2175.89
# Home Value Appreciaion: 6.0%
# 49000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00                   0           4,220.00
# 1    1.00   12.00          12.00                   0           8,700.00
# 2    2.00   24.00          12.00                   0           8,960.00
# 3    3.00   36.00          12.00                   0           9,230.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 80e3,
    rehab_cost = 0,
    after_repair_value = 400e3,
    monthly_rent=0
);
# Out:
# Acquisition:
# Down Payment: $80000.0
# Loan Amount: $324000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2047.90
# Home Value Appreciaion: $6.0%
#
# Rehab:
# Holding costs: $16212.40
# Monthly P&I: $2047.90
# Rehab time: 6 months
# Owning expenses: $654.1666666666667
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $2702.07
# Monthly Cashflow: $-2702.07
# NOI: $-7850.000000000001
#
# Refinance:
# Loan Amount: $324000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2047.90
# Home Value Appreciaion: 6.0%
# 84000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00                   0           3,930.00
# 1    1.00   12.00          12.00                   0           8,090.00
# 2    2.00   24.00          12.00                   0           8,330.00
# 3    3.00   36.00          12.00                   0           8,580.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 20e3,
    rehab_cost = 0,
    after_repair_value = 400e3,
    monthly_rent=0
);
# Out:
# Acquisition:
# Down Payment: $20000.0
# Loan Amount: $384000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2427.14
# Home Value Appreciaion: $6.0%
#
# Rehab:
# Holding costs: $18787.85
# Monthly P&I: $2427.14
# Rehab time: 6 months
# Owning expenses: $704.1666666666667
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $3131.31
# Monthly Cashflow: $-3131.31
# NOI: $-8450.000000000004
#
# Refinance:
# Loan Amount: $324000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2047.90
# Home Value Appreciaion: 6.0%
# 24000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00                   0           4,220.00
# 1    1.00   12.00          12.00                   0           8,700.00
# 2    2.00   24.00          12.00                   0           8,960.00
# 3    3.00   36.00          12.00                   0           9,230.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 20e3,
    rehab_cost = 25e3,
    after_repair_value = 450e3,
    monthly_rent=0
);
# Out:
# Acquisition:
# Down Payment: $20000.0
# Loan Amount: $384000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2427.14
# Home Value Appreciaion: $6.0%
#
# Rehab:
# Holding costs: $18787.85
# Monthly P&I: $2427.14
# Rehab time: 6 months
# Owning expenses: $704.1666666666667
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $3131.31
# Monthly Cashflow: $-3131.31
# NOI: $-8450.000000000004
#
# Refinance:
# Loan Amount: $364500.0
# Loan Points/Fees: $4500.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2303.89
# Home Value Appreciaion: 6.0%
# 49000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00                   0           4,220.00
# 1    1.00   12.00          12.00                   0           8,700.00
# 2    2.00   24.00          12.00                   0           8,960.00
# 3    3.00   36.00          12.00                   0           9,230.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 20e3,
    rehab_cost = 50e3,
    after_repair_value = 500e3,
    monthly_rent=0
);
# Out:
# Acquisition:
# Down Payment: $20000.0
# Loan Amount: $384000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2427.14
# Home Value Appreciaion: $6.0%
#
# Rehab:
# Holding costs: $18787.85
# Monthly P&I: $2427.14
# Rehab time: 6 months
# Owning expenses: $704.1666666666667
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $3131.31
# Monthly Cashflow: $-3131.31
# NOI: $-8450.000000000004
#
# Refinance:
# Loan Amount: $405000.0
# Loan Points/Fees: $5000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2559.88
# Home Value Appreciaion: 6.0%
# 74000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00                   0           4,220.00
# 1    1.00   12.00          12.00                   0           8,700.00
# 2    2.00   24.00          12.00                   0           8,960.00
# 3    3.00   36.00          12.00                   0           9,230.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 20e3,
    rehab_cost = 50e3,
    after_repair_value = 550e3,
    monthly_rent=0
);
# Out:
# Acquisition:
# Down Payment: $20000.0
# Loan Amount: $384000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2427.14
# Home Value Appreciaion: $6.0%
#
# Rehab:
# Holding costs: $18787.85
# Monthly P&I: $2427.14
# Rehab time: 6 months
# Owning expenses: $704.1666666666667
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $3131.31
# Monthly Cashflow: $-3131.31
# NOI: $-8450.000000000004
#
# Refinance:
# Loan Amount: $445500.0
# Loan Points/Fees: $5500.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2815.86
# Home Value Appreciaion: 6.0%
# 74000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00                   0           4,220.00
# 1    1.00   12.00          12.00                   0           8,700.00
# 2    2.00   24.00          12.00                   0           8,960.00
# 3    3.00   36.00          12.00                   0           9,230.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 10e3,
    rehab_cost = 0,
    after_repair_value = 400e3,
    monthly_rent=0,
    value_appreciation=0.03
);
# Out:
# Acquisition:
# Down Payment: $10000.0
# Loan Amount: $394000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2490.35
# Owning Expenses: $712.50
# Monthly Outflow: $3202.85
# Home Value Appreciaion: 3.0%
#
# Rehab:
# Rehab cost: $0.00
# Holding costs: $19217.09
# Monthly P&I: $2490.35
# Rehab time: 6 months
# Owning expenses: $712.5
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $3202.85
# Monthly Cashflow: $-3202.85
# NOI: $-8550.0
#
# Refinance:
# Loan Amount: $324000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2047.90
# Home Value Appreciaion: 3.0%
# 14000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00                   0           4,280.00
# 1    1.00   12.00          12.00                   0           8,810.00
# 2    2.00   24.00          12.00                   0           9,070.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 10e3,
    rehab_cost = 0,
    after_repair_value = 400e3,
    monthly_rent=0,
    value_appreciation=0.03
);
# Out:
# Acquisition:
# Down Payment: $10000.0
# Loan Amount: $394000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2490.35
# Owning Expenses: $712.50
# Monthly Outflow: $3202.85
# Home Value Appreciaion: 3.0%
#
# Rehab:
# Rehab cost: $0.00
# Holding costs: $19217.09
# Monthly P&I: $2490.35
# Rehab time: 6 months
# Owning expenses: $712.5
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $3202.85
# Monthly Cashflow: $-3202.85
# NOI: $-8550.0
#
# Refinance:
# Loan Amount: $324000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2047.90
# Home Value Appreciaion: 3.0%
# 14000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00                   0           4,280.00
# 1    1.00   12.00          12.00                   0           8,810.00
# 2    2.00   24.00          12.00                   0           9,070.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 10e3,
    rehab_cost = 0,
    after_repair_value = 400e3,
    monthly_rent=0,
    value_appreciation=0.0,
    opex_inflation=0.
);
# Out:
# Acquisition:
# Down Payment: $10000.0
# Loan Amount: $394000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2490.35
# Owning Expenses: $712.50
# Monthly Outflow: $3202.85
# Home Value Appreciaion: 0.0%
#
# Rehab:
# Rehab cost: $0.00
# Holding costs: $19217.09
# Monthly P&I: $2490.35
# Rehab time: 6 months
# Owning expenses: $712.5
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $3202.85
# Monthly Cashflow: $-3202.85
# NOI: $-8550.0
#
# Refinance:
# Loan Amount: $324000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2047.90
# Home Value Appreciaion: 0.0%
# 14000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00                   0           4,280.00
# 1    1.00   12.00          12.00                   0           8,550.00
# 2    2.00   24.00          12.00                   0           8,550.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 400e3,
    rehab_cost = 0,
    after_repair_value = 400e3,
    monthly_rent=0,
    value_appreciation=0.0,
    opex_inflation=0.,
    refi_loan_frac=0
);
# Out:
# Acquisition:
# Down Payment: $400000.0
# Loan Amount: $4000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $25.28
# Owning Expenses: $387.50
# Monthly Outflow: $412.78
# Home Value Appreciaion: 0.0%
#
# Rehab:
# Rehab cost: $0.00
# Holding costs: $2476.70
# Monthly P&I: $25.28
# Rehab time: 6 months
# Owning expenses: $387.5
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $412.78
# Monthly Cashflow: $-412.78
# NOI: $-4650.0
#
# Refinance:
# Loan Amount: $4000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $25.28
# Home Value Appreciaion: 0.0%
# 404000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00                   0           2,320.00
# 1    1.00   12.00          12.00                   0           4,650.00
# 2    2.00   24.00          12.00                   0           4,650.00
# ...

# %%
propert_df = property_performance(
    purchase_price = 400e3,
    downpayment = 400e3,
    rehab_cost = 0,
    after_repair_value = 400e3,
    monthly_rent=0,
    value_appreciation=0.03,
    opex_inflation=0.,
    refi_loan_frac=0.8
)
# Out:
# Acquisition:
# Down Payment: $400000.0
# Loan Amount: $4000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $25.28
# Owning Expenses: $387.50
# Monthly Outflow: $412.78
# Home Value Appreciaion: 3.0%
#
# Rehab:
# Rehab cost: $0.00
# Holding costs: $2476.70
# Monthly P&I: $25.28
# Rehab time: 6 months
# Owning expenses: $387.5
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $412.78
# Monthly Cashflow: $-412.78
# NOI: $-4650.0
#
# Refinance:
# Loan Amount: $324000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $2047.90
# Home Value Appreciaion: 3.0%
# 404000.0
#      Year   Month Renting Months Total Annual Income Operating Expenses  \
# 0       0       0           6.00                   0           2,320.00
# 1    1.00   12.00          12.00                   0           4,650.00
# 2    2.00   24.00          12.00                   0           4,650.00
# ...

# %%
propert_df
# Out:
#     Year  Month  Renting Months  Total Annual Income  Operating Expenses  \
# 0      0      0               6                  0.0              2325.0
# 1      1     12              12                  0.0              4650.0
# 2      2     24              12                  0.0              4650.0
# 3      3     36              12                  0.0              4650.0
# 4      4     48              12                  0.0              4650.0
# 5      5     60              12                  0.0              4650.0
# 6      6     72              12                  0.0              4650.0
# 7      7     84              12                  0.0              4650.0
# 8      8     96              12                  0.0              4650.0
# 9      9    108              12                  0.0              4650.0
# 10    10    120              12                  0.0              4650.0
# 11    11    132              12                  0.0              4650.0
# ...

# %%
from real_estate.aggregate import stocks_rent_performance
stocks_df = stocks_rent_performance(0, 30, 100e3)
# Out:
#      Year Total Annual Income Operating Expenses Rent Payment  \
# 0       0                   0           2,400.00    24,000.00
# 1    1.00                   0           2,400.00    24,000.00
# 2    2.00                   0           2,400.00    24,000.00
# 3    3.00                   0           2,400.00    24,000.00
# 4    4.00                   0           2,400.00    24,000.00
# 5    5.00                   0           2,400.00    24,000.00
# 6    6.00                   0           2,400.00    24,000.00
# 7    7.00                   0           2,400.00    24,000.00
# 8    8.00                   0           2,400.00    24,000.00
# 9    9.00                   0           2,400.00    24,000.00
# 10  10.00                   0           2,400.00    24,000.00
# 11  11.00                   0           2,400.00    24,000.00
# 12  12.00                   0           2,400.00    24,000.00
# 13  13.00                   0           2,400.00    24,000.00
# ...

# %%
property_performance(
    purchase_price = 400e3,
    downpayment = 400e3,
    rehab_cost = 0,
    after_repair_value = 400e3,
    monthly_rent=0,
    value_appreciation=0.0,
    opex_inflation=0.,
    refi_loan_frac=0
);
# Out:
# Acquisition:
# Down Payment: $400000.0
# Loan Amount: $4000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $25.28
# Owning Expenses: $387.50
# Monthly Outflow: $412.78
# Home Value Appreciaion: 0.0%
#
# Rehab:
# Rehab cost: $0.00
# Holding costs: $2476.70
# Monthly P&I: $25.28
# Rehab time: 6 months
# Owning expenses: $387.5
#
# Initial Rental Period:
# Monthly Income: $0
# Monthly Expenses: $412.78
# Monthly Cashflow: $-412.78
# NOI: $-4650.0
#
# Refinance:
# Loan Amount: $4000.0
# Loan Points/Fees: $4000.0
# Loan Interest Rate: 6.5%
# Monthly P&I: $25.28
# Home Value Appreciaion: 0.0%
# 404000.0
#    Year  Month Renting Months Total Annual Income Operating Expenses  \
# 0     0      0           6.00                   0           2,320.00
# 1  1.00  12.00          12.00                   0           4,650.00
# 2  2.00  24.00          12.00                   0           4,650.00
# 3  3.00  36.00          12.00                   0           4,650.00
# ...
